# %%
import pandas as pd
import lib.db_controll as db
data = db.db_select()
pd_data = pd.DataFrame(data)
pd_data.columns = ['ranking','game','month','year','hours_watched','hours_streamed','peak_views','peak_channels','streams','avg_viewers','avg_channels','avg_viewer_ratio']
pd_data = pd_data.drop(['peak_views','peak_channels'],axis=1)

# %%
# Out:
#       ranking                              game  month  year  hours_watched  \
# 0           2  Counter-Strike: Global Offensive      2  2016       44933218
# 1           2  Counter-Strike: Global Offensive      3  2016       71963213
# 2           2  Counter-Strike: Global Offensive      4  2016       71723213
# 3           4  Counter-Strike: Global Offensive      5  2016       44882927
# 4           3  Counter-Strike: Global Offensive      6  2016       36137071
# ...       ...                               ...    ...   ...            ...
# 5578       61                         Days Gone      5  2021        3952290
# 5579      102                         Days Gone      6  2021        1744926
# 5580      186                         Days Gone      8  2021         830574
# 5581       54                     Axie Infinity      8  2021        4868904
# 5582       58                     Axie Infinity      9  2021        4000649
#
# ...
